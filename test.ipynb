# %%
import pandas as pd
import os
import data.data_load as data_load
# Out:
# 2025-12-13 15:16:34.900 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
import data.sqlite_reader as sq

# %%
a = sq.get_all_params()

# %%
type(a)
# Out:
# list

# %%
a[0][0]
# Out:
# '["ADRAK DEVELOPERS LLC", "AL ADRAK TRADING AND CONTRACTING COMPANY LLC"]'

# %%
import json

companies_tuple = tuple(json.loads(a[0][0]))
codes_tuple = tuple(json.loads(a[0][1]))

# %%
companies_tuple
# Out:
# tuple

# %%
username='admin'
import data.sqlqueries as sq
import data.sqlreader as sr
sr.fetch_sql_data(f"SELECT * FROM dashboard_access WHERE username = '{username}'")
# Out:
#   USERNAME DASHBOARDACCESS SUPERUSER SALES FINANCE PURCHASE HR
# 0    admin               T         T     T       T        T  T
